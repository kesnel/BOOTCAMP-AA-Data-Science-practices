# %%
import pandas as pd

pk = pd.read_csv("docs/pokemon_data.csv")
pk.head(10)

# pk_xlsx = pd.read_excel("docs/pokemon_data.xlsx")
# pk.head(15)

# pk_txt = pd.read_csv("docs/pokemon_data.txt", delimiter='\t')
# pk_txt

# pk.tail(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
# Print the headers
pk.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Print specific column
# pk["Name"]
pk[["#","Name","Defense"]].head(10)
# Out:
#    #                       Name  Defense
# 0  1                  Bulbasaur       49
# 1  2                    Ivysaur       63
# 2  3                   Venusaur       83
# 3  3      VenusaurMega Venusaur      123
# 4  4                 Charmander       43
# 5  5                 Charmeleon       58
# 6  6                  Charizard       78
# 7  6  CharizardMega Charizard X      111
# 8  6  CharizardMega Charizard Y       78
# 9  7                   Squirtle       65

# %%
# Select LOC
pk.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
# Looking for specific items with Loc
pk.loc[pk["Type 1"] == "Fire"]
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 42  37                     Vulpix   Fire     NaN  38      41       40
# 43  38                  Ninetales   Fire     NaN  73      76       75
# 63  58                  Growlithe   Fire     NaN  55      70       45
# 64  59                   Arcanine   Fire     NaN  90     110       80
# 83  77                     Ponyta   Fire     NaN  50      85       55
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4        60       50     65           1      False
# 5        80       65     80           1      False
# ...

# %%
# Sorting/Describing
pk.sort_values(["Type 1","HP"], ascending=[1,1]).head(10)
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292    Shedinja    Bug   Ghost   1      90       45       30       30
# 230  213     Shuckle    Bug    Rock  20      10      230       10      230
# 462  415      Combee    Bug  Flying  30      30       42       30       42
# 603  543    Venipede    Bug  Poison  30      45       59       30       39
# 314  290     Nincada    Bug  Ground  31      45       90       30       30
# 51    46       Paras    Bug   Grass  35      70       55       45       55
# 446  401   Kricketot    Bug     NaN  37      25       41       25       41
# 732  664  Scatterbug    Bug     NaN  38      35       40       27       25
# 16    13      Weedle    Bug  Poison  40      35       30       20       20
# 179  165      Ledyba    Bug  Flying  40      20       30       40       80
#
#      Speed  Generation  Legendary
# 316     40           3      False
# 230      5           2      False
# 462     70           4      False
# ...
